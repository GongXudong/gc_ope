# %%
import numpy as np

# %% [markdown]
# ## FlyCraft

# %%
# GC-SAC
a = np.array([0.08074658474001381, 0.07906932146979509, 0.049451258455804926, 0.06028139787949628, 0.05020858357394779,])
b = np.array([0.014072440852885193, 0.014023595482431235, 0.007925760041472675, 0.034793729827332975, 0.03097532257594575])
a.mean(), a.std(), b.mean(), b.std()

# %%
# OMEGA
a = np.array([0.10490543721515098, 0.05258833233110561, 0.06248293036061137, 0.03230872414522382, 0.070495943447636])
b = np.array([0.010516449197053251, 0.018232725364936427, 0.0026084269453971846, 0.01901449991884795, 0.008658580875323526])
a.mean(), a.std(), b.mean(), b.std()

# %% [markdown]
# ## Reach

# %%
# GC-SAC
a = np.array([0.035834084531016934, 0.05553535147840346, 0.04209440464568619, 0.04631822622016794, 0.04799265756249518])
b = np.array([0.026467588655445757, 0.0010187763299624591, 0.0013461082052260013, 0.0009727888405736594, 0.00020142077934430053])
a.mean(), a.std(), b.mean(), b.std()
# Out:
# (np.float64(0.04555494488755395),
#  np.float64(0.006520797835140078),
#  np.float64(0.006001336562110436),
#  np.float64(0.010240018042412116))

# %%
# OMEGA
a = np.array([0.046179375310817145, 0.029598527131951623, 0.13159116738581442, 0.07040194660846819, 0.14903020312946363])
b = np.array([0.000619489888170938, 0.0007887568755774363, 0.000669179013696014, 0.0006667252510788102, 0.0001483397824220809])
a.mean(), a.std(), b.mean(), b.std()
# Out:
# (np.float64(0.085360243913303),
#  np.float64(0.04703067546361098),
#  np.float64(0.0005784981621890559),
#  np.float64(0.00022223065309828324))

# %% [markdown]
# ## Push

# %%
# GC-SAC
a = np.array([0.20869735113855076, 0.1928485834591199, 0.20112210497365132, 0.2245156867777373, 0.18685814193861078])
b = np.array([0.010274444711622735, 0.003638547450730647, 0.0047778154783704105, 0.016219572938562077, 0.015827935145832413])
a.mean(), a.std(), b.mean(), b.std()
# Out:
# (np.float64(0.20280837365753404),
#  np.float64(0.013132694418347567),
#  np.float64(0.010147663145023657),
#  np.float64(0.005298178992718571))

# %%
# OMEGA
a = np.array([0.1784345447280048, 0.18757813100578388, 0.1812820438825288, 0.2005501894338277, 0.1869907545687294])
b = np.array([0.006517709959196509, 0.028259924952197882, 0.006509635485317358, 0.004009218435865617, 0.0017731524765066933])
a.mean(), a.std(), b.mean(), b.std()
# Out:
# (np.float64(0.1869671327237749),
#  np.float64(0.007615754716626694),
#  np.float64(0.009413928261816812),
#  np.float64(0.00958735553889631))

# %% [markdown]
# ## Slide

# %%
# GC-SAC
a = np.array([0.28987562029529657, 0.2521543371536764, 0.25202541017895935, 0.2505458530770591, 0.26329022534557983])
b = np.array([0.014165703015560287, 0.020032381263162275, 0.014637367186551455, 0.0038868026451769544, 0.008389040995740494])
a.mean(), a.std(), b.mean(), b.std()
# Out:
# (np.float64(0.2615782892101142),
#  np.float64(0.01486911355160217),
#  np.float64(0.012222259021238293),
#  np.float64(0.005563831860709795))

# %%
# OMEGA
a = np.array([0.25579094940738767, 0.25887038383316646, 0.2552788283922659, 0.2170921737001324, 0.2382872686572544])
b = np.array([0.007237616181960239, 0.013661650399274755, 0.0026779881807232086, 0.0015908783080675563, 0.004042185866791715])
a.mean(), a.std(), b.mean(), b.std()
# Out:
# (np.float64(0.24506392079804135),
#  np.float64(0.01573768440038856),
#  np.float64(0.0058420637873634945),
#  np.float64(0.004345503750317587))
